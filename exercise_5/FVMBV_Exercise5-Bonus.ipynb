# %% [markdown]
# ## FVMBV Advanced Methods of Medical Image Analysis
# ### Exercise 5 - Random Walk and Random Ferns

# %% [markdown]
# #### Bonus task
#
# Please carefully follow the instructions in the exercise sheet.

# %%
# prepare jupyter extensions, download adapted pizarra and activate

# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# !git clone https://github.com/mattiaspaul/pizarra-nb.git
# !cd pizarra-nb; jupyter nbextension install pizarra-nb --user
# !jupyter nbextension enable pizarra-nb/pizarra 
# !jupyter nbextension enable pizarra-nb/sketchpad 
# !jupyter nbextension enable pizarra-nb/html2canvas
# !pip install pyamg

# %%
# download data and utility functions 
# !wget "https://images.squarespace-cdn.com/content/v1/54972dbae4b0af001f2cf57b/1453187747509-45QX15GLVM62L79D4LD0/ke17ZwdGBToddI8pDm48kFTEgwhRQcX9r3XtU0e50sUUqsxRUqqbr1mOJYKfIPR7LoDQ9mXPOjoJoqy81S2I8N_N4V1vUb5AoIIIbLZhVYxCRW4BPu10St3TBAUQYVKcW7uEhC96WQdj-SwE5EpM0lAopPba9ZX3O0oeNTVSRxdHAmtcci_6bmVLoSDQq_pb/image-asset.jpeg?format=1500w" -O calvin.jpg
# !wget "https://cloud.imi.uni-luebeck.de/s/HiXNn4o6LBBBGSS/download" -O utils_rw_scribble.py

# %%
# run imports

from scipy.sparse import csr_matrix
import pyamg
import imageio
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from utils_rw_scribble import *

# %%
# read image data

img = imageio.imread('calvin.jpg')[::2,::2,:]
input_framed = frame_image(img)

# %%
# leave this cell empty (output of pizarra will appear)

# %%
# keep this cell selected when clicking on pizarra icon (brush) 
plt.imshow(input_framed); plt.show();

# %%
#### TODO
# your random walk segmentation (from Task 1)

def random_walk(img_gray,labels):
    return probabilities

# %%
# process image and visualize results 

img = imageio.imread('calvin.jpg')[::2,::2,:]
input_framed = frame_image(img)
cropped_out,img_gray = crop_image(input_framed,src) #src is output of pizarra!
labels,unique_rgb = extract_scribbles(cropped_out)
display_colours(unique_rgb)

# todo 
probabilities = # random_walk(...) 
rgb = # overlay_segment(...) 
plt.imshow(rgb)
plt.show()
