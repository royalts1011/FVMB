# %% [markdown]
# ### FVMBV Exercise 3 - Stereo and Dynamic Programming

# %%
# run imports
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
# read data
data_in = torch.load('exercise3_stereo_pytorch.pth')
fixed = data_in['fixed']
moving = data_in['moving']
data = data_in['data']

H, W = fixed.shape

# %%
# visualize input data
plt.imshow(fixed,'gray')
plt.show()
plt.imshow(moving,'gray')
plt.show()

# %% [markdown]
# #### Task 1 - Computation of the stereo data term (4 pts)

# %%
# todo: compute gradients in x-direction

# todo: define constants

# todo: unfold moving image for sliding window operation

# todo: compute data cost

# %% [markdown]
# #### Task 2 - Dynamic programming (4 pts)

# %%
# todo: compute regular tensor

# todo: init first column

# todo: implement message passing (forward)

# todo: implement message passing (backward)

# todo: compare with results from lecture

# %% [markdown]
# #### Task 3a - Scanline optimization (2 pts)

# %%
# todo: compute regular tensor

# todo: estimate disparity

# %% [markdown]
# #### Task 3b - Comparison optical flow with discrete optimisation (2 pts)
#
#  Explain in about 200 (own) words the advantages and disadvantages of discrete motion estimation with dynamic programming compared to continuous optimisation of the optical flow:

# %% [markdown]
# Put your text here

# %% [markdown]
# #### Bonus task (up to 4 pts)

# %%
# todo
